# %%
# %matplotlib inline #will print plots withincode, not external pop up

# import packages
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# set up plot size and dimention
mpl.rc('savefig', dpi=200) #resolution
plt.style.use('ggplot')
plt.rcParams['xtick.minor.size'] = 0
plt.rcParams['ytick.minor.size'] = 0

# %%
unemployment = pd.read_csv('data/country_total.csv')
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
type(unemployment)
# Out:
# pandas.core.frame.DataFrame

# %%
unemployment.head(10) # see first ten lines
# Out:
#   country seasonality    month  unemployment  unemployment_rate
# 0      at         nsa  1993.01        171000                4.5
# 1      at         nsa  1993.02        175000                4.6
# 2      at         nsa  1993.03        166000                4.4
# 3      at         nsa  1993.04        157000                4.1
# 4      at         nsa  1993.05        147000                3.9
# 5      at         nsa  1993.06        134000                3.5
# 6      at         nsa  1993.07        128000                3.4
# 7      at         nsa  1993.08        130000                3.4
# 8      at         nsa  1993.09        132000                3.5
# 9      at         nsa  1993.10        141000                3.7

# %%
unemployment.tail(10) # see last ten lines
# Out:
#       country seasonality    month  unemployment  unemployment_rate
# 20786      uk       trend  2010.01       2456000                7.9
# 20787      uk       trend  2010.02       2463000                7.9
# 20788      uk       trend  2010.03       2437000                7.8
# 20789      uk       trend  2010.04       2419000                7.8
# 20790      uk       trend  2010.05       2419000                7.7
# 20791      uk       trend  2010.06       2429000                7.7
# 20792      uk       trend  2010.07       2422000                7.7
# 20793      uk       trend  2010.08       2429000                7.7
# 20794      uk       trend  2010.09       2447000                7.8
# 20795      uk       trend  2010.10       2455000                7.8

# %%
len(unemployment) # rows
# Out:
# 20796

# %%
unemployment.shape # rows, columns
# Out:
# (20796, 5)

# %%
unemployment.rename(columns={'month' : 'year_month'}, inplace=True) #rename month column

# %%
unemployment['year_month'].head()
# Out:
# 0    1993.01
# 1    1993.02
# 2    1993.03
# 3    1993.04
# 4    1993.05
# Name: year_month, dtype: float64

# %%
unemployment[2:5]
# Out:
#   country seasonality  year_month  unemployment  unemployment_rate
# 2      at         nsa     1993.03        166000                4.4
# 3      at         nsa     1993.04        157000                4.1
# 4      at         nsa     1993.05        147000                3.9

# %%
city = pd.DataFrame({'city_stats' : [632, 1638, 569, 115],
                         'other_feature' : [438, 833, 234, 298]},
                         index=['Glasgow', 'Edinburgh', 'London', 'Bristol']) # create a dataframe

# %%
city
# Out:
#            city_stats  other_feature
# Glasgow           632            438
# Edinburgh        1638            833
# London            569            234
# Bristol           115            298

# %%
city.loc['Glasgow'] # just associated with Glasgow, returns a series
# Out:
# city_stats       632
# other_feature    438
# Name: Glasgow, dtype: int64

# %%
unemployment.iloc[[1, 5, 6, 8]] #row 1,5,6,8
# Out:
#   country seasonality  year_month  unemployment  unemployment_rate
# 1      at         nsa     1993.02        175000                4.6
# 5      at         nsa     1993.06        134000                3.5
# 6      at         nsa     1993.07        128000                3.4
# 8      at         nsa     1993.09        132000                3.5

# %%
unemployment.iloc[25:50:5]
# Out:
#    country seasonality  year_month  unemployment  unemployment_rate
# 25      at         nsa     1995.02        174000                4.5
# 30      at         nsa     1995.07        123000                3.3
# 35      at         nsa     1995.12        175000                4.7
# 40      at         nsa     1996.05        159000                4.3
# 45      at         nsa     1996.10        146000                3.9

# %%
unemployment['year'] = unemployment['year_month'].astype(int) #extract integer part of value, trunacates decimals

# %%
unemployment #saved right now as dataframe in python but not dataset
# Out:
#       country seasonality  year_month  unemployment  unemployment_rate  year
# 0          at         nsa     1993.01        171000                4.5  1993
# 1          at         nsa     1993.02        175000                4.6  1993
# 2          at         nsa     1993.03        166000                4.4  1993
# 3          at         nsa     1993.04        157000                4.1  1993
# 4          at         nsa     1993.05        147000                3.9  1993
# ...       ...         ...         ...           ...                ...   ...
# 20791      uk       trend     2010.06       2429000                7.7  2010
# 20792      uk       trend     2010.07       2422000                7.7  2010
# 20793      uk       trend     2010.08       2429000                7.7  2010
# 20794      uk       trend     2010.09       2447000                7.8  2010
# 20795      uk       trend     2010.10       2455000                7.8  2010
#
# [20796 rows x 6 columns]

# %%
unemployment['month'] = ((unemployment['year_month'] - unemployment['year']) * 100).round(0).astype(int)

# %%
unemployment = unemployment[['country', 'seasonality',
                             'year_month', 'year', 'month',
                             'unemployment', 'unemployment_rate']] #reorder columns

# %%
unemployment
# Out:
#       country seasonality  year_month  year  month  unemployment  \
# 0          at         nsa     1993.01  1993      1        171000
# 1          at         nsa     1993.02  1993      2        175000
# 2          at         nsa     1993.03  1993      3        166000
# 3          at         nsa     1993.04  1993      4        157000
# 4          at         nsa     1993.05  1993      5        147000
# ...       ...         ...         ...   ...    ...           ...
# 20791      uk       trend     2010.06  2010      6       2429000
# 20792      uk       trend     2010.07  2010      7       2422000
# 20793      uk       trend     2010.08  2010      8       2429000
# 20794      uk       trend     2010.09  2010      9       2447000
# 20795      uk       trend     2010.10  2010     10       2455000
#
#        unemployment_rate
# 0                    4.5
# 1                    4.6
# 2                    4.4
# 3                    4.1
# 4                    3.9
# ...                  ...
# ...

# %%
# country dataset
countries = pd.read_csv('data/countries.csv')

# %%
countries
# Out:
#    country google_country_code country_group  \
# 0       at                  AT            eu
# 1       be                  BE            eu
# 2       bg                  BG            eu
# 3       hr                  HR        non-eu
# 4       cy                  CY            eu
# 5       cz                  CZ            eu
# 6       dk                  DK            eu
# 7       ee                  EE            eu
# 8       fi                  FI            eu
# 9       fr                  FR            eu
# 10      de                  DE            eu
# 11      gr                  GR            eu
# 12      hu                  HU            eu
# 13      ie                  IE            eu
# 14      it                  IT            eu
# 15      lv                  LV            eu
# 16      lt                  LT            eu
# 17      lu                  LU            eu
# 18      mt                  MT            eu
# 19      nl                  NL            eu
# ...

# %%
country_names = countries[['country', 'country_group', 'name_en']] #select certain columns

# %%
country_names.head(5)
# Out:
#   country country_group   name_en
# 0      at            eu   Austria
# 1      be            eu   Belgium
# 2      bg            eu  Bulgaria
# 3      hr        non-eu   Croatia
# 4      cy            eu    Cyprus

# %%
unemployment = pd.merge(unemployment, country_names, on='country') # merge datasets

# %% [markdown]
# Merging is often more complex than this example. If you want to merge on multiple columns, you can pass a list of column names to the on parameter.
#
# pd.merge(first, second, on=['name', 'id'])
# You might even need to merge on columns with different names. To do so, use the left_on and right_on parameters, where the first listed DataFrame is the "left" one and the second is the "right." It might look something this.
#
# pd.merge(one, two, left_on='city', right_on='city_name')
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
unemployment.head()
# Out:
#   country seasonality  year_month  year  month  unemployment  \
# 0      at         nsa     1993.01  1993      1        171000
# 1      at         nsa     1993.02  1993      2        175000
# 2      at         nsa     1993.03  1993      3        166000
# 3      at         nsa     1993.04  1993      4        157000
# 4      at         nsa     1993.05  1993      5        147000
#
#    unemployment_rate country_group  name_en
# 0                4.5            eu  Austria
# 1                4.6            eu  Austria
# 2                4.4            eu  Austria
# 3                4.1            eu  Austria
# 4                3.9            eu  Austria

# %%
unemployment.name_en.unique() #country names
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Cyprus', 'Czech Republic',
#        'Germany (including  former GDR from 1991)', 'Denmark', 'Estonia',
#        'Spain', 'Finland', 'France', 'Greece', 'Croatia', 'Hungary',
#        'Ireland', 'Italy', 'Lithuania', 'Luxembourg', 'Latvia', 'Malta',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Sweden',
#        'Slovenia', 'Slovakia', 'Turkey', 'United Kingdom'], dtype=object)

# %%
len(unemployment.name_en.unique()) ## of countries
# Out:
# 30

# %%
unemployment['name_en'].value_counts().sort_index() # counts of unique values for series
# Out:
# name_en
# Austria                                       648
# Belgium                                      1008
# Bulgaria                                      576
# Croatia                                       324
# Cyprus                                        396
# Czech Republic                                468
# Denmark                                      1008
# Estonia                                       387
# Finland                                       828
# France                                       1008
# Germany (including  former GDR from 1991)     504
# Greece                                        450
# Hungary                                       576
# Ireland                                      1008
# Italy                                         924
# Latvia                                        459
# Lithuania                                     459
# Luxembourg                                   1008
# Malta                                         576
# ...

# %%
unemployment['year'].min(), unemployment['year'].max()
# Out:
# (1983, 2010)

# %%
unemployment['unemployment_rate'].isnull().sum()
# Out:
# 945

# %%
unemployment['unemployment_rate_null'] = unemployment['unemployment_rate'].isnull() # False = we have data

# %%
unemployment
# Out:
#       country seasonality  year_month  year  month  unemployment  \
# 0          at         nsa     1993.01  1993      1        171000
# 1          at         nsa     1993.02  1993      2        175000
# 2          at         nsa     1993.03  1993      3        166000
# 3          at         nsa     1993.04  1993      4        157000
# 4          at         nsa     1993.05  1993      5        147000
# ...       ...         ...         ...   ...    ...           ...
# 20791      uk       trend     2010.06  2010      6       2429000
# 20792      uk       trend     2010.07  2010      7       2422000
# 20793      uk       trend     2010.08  2010      8       2429000
# 20794      uk       trend     2010.09  2010      9       2447000
# 20795      uk       trend     2010.10  2010     10       2455000
#
#        unemployment_rate country_group         name_en  unemployment_rate_null
# 0                    4.5            eu         Austria                   False
# ...

# %%
# group in () what operation we would like to perform following
unemployment.groupby('name_en')['unemployment_rate_null'].sum() # count number of missing values
# Out:
# name_en
# Austria                                        0
# Belgium                                        0
# Bulgaria                                     180
# Croatia                                      216
# Cyprus                                         0
# Czech Republic                                 0
# Denmark                                        0
# Estonia                                        0
# Finland                                        0
# France                                         0
# Germany (including  former GDR from 1991)      0
# Greece                                         0
# Hungary                                       36
# Ireland                                        0
# Italy                                          0
# Latvia                                         0
# Lithuania                                      0
# Luxembourg                                     0
# Malta                                        180
# ...

# %%
# saving as data frame
# can look at API reference
unemployment_rate = unemployment.groupby('name_en', as_index=False)['unemployment_rate_null'].sum()

# %%
unemployment_rate
# Out:
#                                       name_en  unemployment_rate_null
# 0                                     Austria                       0
# 1                                     Belgium                       0
# 2                                    Bulgaria                     180
# 3                                     Croatia                     216
# 4                                      Cyprus                       0
# 5                              Czech Republic                       0
# 6                                     Denmark                       0
# 7                                     Estonia                       0
# 8                                     Finland                       0
# 9                                      France                       0
# 10  Germany (including  former GDR from 1991)                       0
# 11                                     Greece                       0
# ...

# %%
# group by name of countries, count values, add column n_obs
unemployment_rate['n_obs'] = unemployment.groupby('name_en')['name_en'].count().values

# %%
unemployment_rate
# Out:
#                                       name_en  unemployment_rate_null  n_obs
# 0                                     Austria                       0    648
# 1                                     Belgium                       0   1008
# 2                                    Bulgaria                     180    576
# 3                                     Croatia                     216    324
# 4                                      Cyprus                       0    396
# 5                              Czech Republic                       0    468
# 6                                     Denmark                       0   1008
# 7                                     Estonia                       0    387
# 8                                     Finland                       0    828
# 9                                      France                       0   1008
# 10  Germany (including  former GDR from 1991)                       0    504
# ...

# %%
unemployment_rate['null_percentage'] = unemployment_rate['unemployment_rate_null'] / unemployment_rate['n_obs']
# divide columns

# %%
unemployment_rate
# Out:
#                                       name_en  unemployment_rate_null  n_obs  \
# 0                                     Austria                       0    648
# 1                                     Belgium                       0   1008
# 2                                    Bulgaria                     180    576
# 3                                     Croatia                     216    324
# 4                                      Cyprus                       0    396
# 5                              Czech Republic                       0    468
# 6                                     Denmark                       0   1008
# 7                                     Estonia                       0    387
# 8                                     Finland                       0    828
# 9                                      France                       0   1008
# 10  Germany (including  former GDR from 1991)                       0    504
# ...

# %%
# save dataframe as csv, make note of delimiter choice, how to separate data
unemployment_rate.to_csv('data/unemployment_missing.csv',index=False, sep=',')

# %%
# drop column
# axis=1 refers to columns. (axis=0 refers to rows.) inplace=True simply modifies the actual DataFrame.
unemployment.drop('unemployment_rate_null', axis=1, inplace=True)

# %%
unemployment.head()
# Out:
#   country seasonality  year_month  year  month  unemployment  \
# 0      at         nsa     1993.01  1993      1        171000
# 1      at         nsa     1993.02  1993      2        175000
# 2      at         nsa     1993.03  1993      3        166000
# 3      at         nsa     1993.04  1993      4        157000
# 4      at         nsa     1993.05  1993      5        147000
#
#    unemployment_rate country_group  name_en
# 0                4.5            eu  Austria
# 1                4.6            eu  Austria
# 2                4.4            eu  Austria
# 3                4.1            eu  Austria
# 4                3.9            eu  Austria

# %%
# exclude missing values, problems only lie in one column so is ok
unemployment_rate_missing = unemployment[unemployment['unemployment_rate'].isnull()]
# unemployment['unemployment_rate'].isnull() produces array of Boolean values
# new data frame where missing values in unemployment rate in unemployment

# %%
unemployment['unemployment_rate'].isnull()[:10]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: unemployment_rate, dtype: bool

# %%
unemployment_rate_missing
# Out:
#       country seasonality  year_month  year  month  unemployment  \
# 1656       bg         nsa     1995.01  1995      1        391000
# 1657       bg         nsa     1995.02  1995      2        387000
# 1658       bg         nsa     1995.03  1995      3        378000
# 1659       bg         nsa     1995.04  1995      4        365000
# 1660       bg         nsa     1995.05  1995      5        346000
# ...       ...         ...         ...   ...    ...           ...
# 19423      sk       trend     1997.08  1997      8        279000
# 19424      sk       trend     1997.09  1997      9        284000
# 19425      sk       trend     1997.10  1997     10        288000
# 19426      sk       trend     1997.11  1997     11        287000
# 19427      sk       trend     1997.12  1997     12        285000
#
#        unemployment_rate country_group   name_en
# 1656                 NaN            eu  Bulgaria
# 1657                 NaN            eu  Bulgaria
# ...

# %%
# drop missing values
unemployment.dropna(subset=['unemployment_rate'], inplace=True)

# %%
# highest unemployment rate
unemployment.sort_values(by='unemployment_rate', ascending=False)[:5]
# Out:
#       country seasonality  year_month  year  month  unemployment  \
# 15526      pl         nsa     2004.02  2004      2       3531000
# 15525      pl         nsa     2004.01  2004      1       3520000
# 15514      pl         nsa     2003.02  2003      2       3460000
# 5663       es          sa     2010.09  2010      9       4773000
# 15527      pl         nsa     2004.03  2004      3       3475000
#
#        unemployment_rate country_group name_en
# 15526               20.9            eu  Poland
# 15525               20.7            eu  Poland
# 15514               20.7            eu  Poland
# 5663                20.6            eu   Spain
# 15527               20.6            eu  Poland

# %%
# see how many observations dropped
unemployment
# Out:
#       country seasonality  year_month  year  month  unemployment  \
# 0          at         nsa     1993.01  1993      1        171000
# 1          at         nsa     1993.02  1993      2        175000
# 2          at         nsa     1993.03  1993      3        166000
# 3          at         nsa     1993.04  1993      4        157000
# 4          at         nsa     1993.05  1993      5        147000
# ...       ...         ...         ...   ...    ...           ...
# 20791      uk       trend     2010.06  2010      6       2429000
# 20792      uk       trend     2010.07  2010      7       2422000
# 20793      uk       trend     2010.08  2010      8       2429000
# 20794      uk       trend     2010.09  2010      9       2447000
# 20795      uk       trend     2010.10  2010     10       2455000
#
#        unemployment_rate country_group         name_en
# 0                    4.5            eu         Austria
# 1                    4.6            eu         Austria
# ...

# %%
unemployment['seasonality'].unique()
# Out:
# array(['nsa', 'sa', 'trend'], dtype=object)

# %%
# stick to seasonally adjusted data 
unemployment[unemployment['seasonality'] == 'sa'].sort_values(by='unemployment_rate', ascending=False)[:5]
# Out:
#       country seasonality  year_month  year  month  unemployment  \
# 5664       es          sa     2010.10  2010     10       4758000
# 5663       es          sa     2010.09  2010      9       4773000
# 5662       es          sa     2010.08  2010      8       4739000
# 5665       es          sa     2010.11  2010     11       4723000
# 15702      pl          sa     2002.10  2002     10       3471000
#
#        unemployment_rate country_group name_en
# 5664                20.6            eu   Spain
# 5663                20.6            eu   Spain
# 5662                20.5            eu   Spain
# 5665                20.4            eu   Spain
# 15702               20.3            eu  Poland

# %%
# drop = construct dataframe without adding a column
# inplace permananetly changes data frame
unemployment.sort_values(by=['name_en', 'year_month'], inplace=True)
unemployment.reset_index(drop=True, inplace=True)

# %%
unemployment.head(10)
# Out:
#   country seasonality  year_month  year  month  unemployment  \
# 0      at         nsa     1993.01  1993      1        171000
# 1      at          sa     1993.01  1993      1        144000
# 2      at       trend     1993.01  1993      1        144000
# 3      at         nsa     1993.02  1993      2        175000
# 4      at          sa     1993.02  1993      2        145000
# 5      at       trend     1993.02  1993      2        145000
# 6      at         nsa     1993.03  1993      3        166000
# 7      at          sa     1993.03  1993      3        147000
# 8      at       trend     1993.03  1993      3        147000
# 9      at         nsa     1993.04  1993      4        157000
#
#    unemployment_rate country_group  name_en
# 0                4.5            eu  Austria
# 1                3.8            eu  Austria
# 2                3.8            eu  Austria
# 3                4.6            eu  Austria
# 4                3.8            eu  Austria
# ...

# %%
# Look at spain since it had highest
spain = unemployment[(unemployment['name_en'] == 'Spain') &
                     (unemployment['seasonality'] == 'sa')]

# %%
# Plot, x axis is plotting as observation
spain['unemployment_rate'].plot(figsize=(12, 8), color='green')
# Out:
# <Axes: >

# %%
# Create data frame for portugal and spain 
ps = unemployment[(unemployment['name_en'].isin(['Portugal', 'Spain'])) &
                  (unemployment['seasonality'] == 'sa')]

# %%
# convert to date time, add column
ps.insert(loc=0, column='date',
          value=pd.to_datetime(ps['year'].astype(str) + '/' + ps['month'].astype(str) + '/1'))

# %%
ps
# Out:
#             date country seasonality  year_month  year  month  unemployment  \
# 14302 1983-01-01      pt          sa     1983.01  1983      1        345000
# 14305 1983-02-01      pt          sa     1983.02  1983      2        348000
# 14308 1983-03-01      pt          sa     1983.03  1983      3        353000
# 14311 1983-04-01      pt          sa     1983.04  1983      4        359000
# 14314 1983-05-01      pt          sa     1983.05  1983      5        366000
# ...          ...     ...         ...         ...   ...    ...           ...
# 17617 2010-08-01      es          sa     2010.08  2010      8       4739000
# 17620 2010-09-01      es          sa     2010.09  2010      9       4773000
# 17623 2010-10-01      es          sa     2010.10  2010     10       4758000
# 17626 2010-11-01      es          sa     2010.11  2010     11       4723000
# 17629 2010-12-01      es          sa     2010.12  2010     12       4672000
#
#        unemployment_rate country_group   name_en
# ...

# %%
# only keep certain columns, rename them, and reshape the DataFrame.
# pivot - 
ps = ps[['date', 'name_en', 'unemployment_rate']]
ps.columns = ['Time Period', 'Country', 'Unemployment Rate']
ps = ps.pivot(index='Time Period', columns='Country', values='Unemployment Rate')
ps.tail()
# Out:
# Country      Portugal  Spain
# Time Period
# 2010-08-01       11.1   20.5
# 2010-09-01       11.1   20.6
# 2010-10-01       11.0   20.6
# 2010-11-01       10.9   20.4
# 2010-12-01       10.9   20.2

# %%
ps.plot(figsize=(10, 8), title='Unemployment Rate\n')
# Out:
# <Axes: title={'center': 'Unemployment Rate\n'}, xlabel='Time Period'>
